# %%
import os
import pickle
import librosa
import librosa.display
import matplotlib
import matplotlib.pyplot
import numpy as np
from tqdm.auto import tqdm
from IPython.display import Audio
import soundfile as sf
import os
import ffmpy
import warnings
import opensmile
import csv
import pandas as pd 

warnings.filterwarnings('ignore')


AUDIOS_FOLDER = "../data/audios/utterances_final"
AUDIOS_FOLDER_WAV = "../data/audios/utterances_final_wav"
AUDIOS_FOLDER__BGR_WAV = "../data/audios/utterances_final_bgr_wav"

# %% [markdown]
# ## Convert mp4 to wav file and remove background noise

# %%
for filename in os.listdir(AUDIOS_FOLDER):
    actual_filename = filename.rsplit(".", maxsplit=1)[0]
    if(filename.endswith(".mp4")):
        os.system('ffmpeg -i {} -acodec pcm_s16le {}.wav'.format(
            os.path.join(AUDIOS_FOLDER, filename), os.path.join(AUDIOS_FOLDER_WAV, actual_filename)))
    else:
        continue
# Out:
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_479.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.71.100
#   Duration: 00:00:04.47, start: 0.000000, bitrate: 356 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 352x262 [SAR 1:1 DAR 176:131], 251 kb/s, 29.97 fps, 29.97 tbr, 29972 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_479.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_337.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:02.86, start: 0.000000, bitrate: 2490 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 2.835000
#       Metadata:
#         title           : 00:10:59.909
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 2368 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_337.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_323.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: mp41mp42isom
#     creation_time   : 2019-02-08T01:09:55.000000Z
#   Duration: 00:00:03.35, start: 0.000000, bitrate: 2742 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1280x720 [SAR 1:1 DAR 16:9], 1200 kb/s, 23.97 fps, 23.98 tbr, 23987 tbn (default)
#     Metadata:
#       creation_time   : 2019-02-08T01:09:55.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       creation_time   : 2019-02-08T01:09:55.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_323.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_445.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:00.50, start: 0.000000, bitrate: 2449 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 0.480000
#       Metadata:
#         title           : 00:02:14.551
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 2082 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 336 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_445.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_11242.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : The Big Bang Theory S08E09
#     encoder         : Lavf57.29.101
#     description     : Encoded By RMTeam
#   Duration: 00:00:09.02, start: 0.000000, bitrate: 690 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 854x480 [SAR 1280:1281 DAR 16:9], 554 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 130 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_11242.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_492.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.71.100
#   Duration: 00:00:05.11, start: 0.000000, bitrate: 346 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 352x262 [SAR 1:1 DAR 176:131], 241 kb/s, 29.97 fps, 29.97 tbr, 29972 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_492.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_486.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:03.69, start: 0.000000, bitrate: 1889 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 3.670000
#       Metadata:
#         title           : 00:02:04.041
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 1762 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_486.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_109.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: mp41mp42isom
#     creation_time   : 2019-02-07T09:11:32.000000Z
#   Duration: 00:00:04.69, start: 0.000000, bitrate: 469 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Main) (avc1 / 0x31637661), yuv420p(progressive), 960x720 [SAR 1:1 DAR 4:3], 193 kb/s, 24.90 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2019-02-07T09:11:32.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2019-02-07T09:11:32.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_109.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_6426.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:06.02, start: 0.000000, bitrate: 433 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 6.000000
#       Metadata:
#         title           : 00:00:00.097
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 720x400 [SAR 80:81 DAR 16:9], 298 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/1_6426.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_135.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.71.100
#   Duration: 00:00:07.54, start: 0.000000, bitrate: 346 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 352x262 [SAR 1:1 DAR 176:131], 241 kb/s, 29.97 fps, 29.97 tbr, 29972 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_135.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_11901.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:16.02, start: 0.000000, bitrate: 635 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 848x480 [SAR 171:170 DAR 3021:1700], 501 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_11901.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_3204.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:08.02, start: 0.000000, bitrate: 332 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 8.000000
#       Metadata:
#         title           : 00:00:00.097
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 624x352 [SAR 255:254 DAR 9945:5588], 196 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/1_3204.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_121.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.71.100
#   Duration: 00:00:02.47, start: 0.000000, bitrate: 256 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 352x262 [SAR 1:1 DAR 176:131], 150 kb/s, 29.97 fps, 29.97 tbr, 29972 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_121.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_7089.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:10.02, start: 0.000000, bitrate: 718 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 852x480, 579 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 131 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_7089.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_7894.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:07.02, start: 0.000000, bitrate: 770 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 848x480 [SAR 171:170 DAR 3021:1700], 635 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 129 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_7894.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_182.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:05.02, start: 0.000000, bitrate: 382 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 5.000000
#       Metadata:
#         title           : 00:00:00.097
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 624x352 [SAR 255:254 DAR 9945:5588], 247 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/1_182.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.71.100
#   Duration: 00:00:04.72, start: 0.000000, bitrate: 356 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 480x360 [SAR 1:1 DAR 4:3], 253 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_1.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_11120.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:04.02, start: 0.000000, bitrate: 730 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 848x480 [SAR 171:170 DAR 3021:1700], 596 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_11120.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_525.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf56.40.101
#   Duration: 00:00:01.69, start: 0.000000, bitrate: 1932 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 1.667000
#       Metadata:
#         title           : 00:02:00.537
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 1811 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_525.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_243.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:03.19, start: 0.000000, bitrate: 2111 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 3.168000
#       Metadata:
#         title           : 00:00:00.000
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 1768 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 344 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_243.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_1003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:08.02, start: 0.000000, bitrate: 569 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 8.000000
#       Metadata:
#         title           : 00:00:00.097
# ...
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_1185.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:03.02, start: 0.000000, bitrate: 492 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 3.000000
#       Metadata:
#         title           : 00:00:00.097
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 624x352 [SAR 255:254 DAR 9945:5588], 357 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/1_1185.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_11529.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     title           : The Big Bang Theory S08E13 - RMTeam, Rapidmoviez.com
#     encoder         : Lavf57.29.101
#     description     : Encoded By RMTeam, Rapidmoviez.com
#   Duration: 00:00:05.02, start: 0.000000, bitrate: 477 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 854x480 [SAR 1280:1281 DAR 16:9], 339 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 130 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_11529.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_448.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 1481 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 2.440000
#       Metadata:
#         title           : 00:04:34.900
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 1343 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 126 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_448.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/1_10810.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.29.101
#   Duration: 00:00:10.02, start: 0.000000, bitrate: 597 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 852x480, 460 kb/s, 23.98 fps, 23.98 tbr, 24k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 129 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/1_10810.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_306.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.71.100
#   Duration: 00:00:09.41, start: 0.000000, bitrate: 380 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x352 [SAR 1:1 DAR 20:11], 278 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 96 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_306.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_312.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 1
#     compatible_brands: mp41mp42isom
#     creation_time   : 2019-02-08T01:05:05.000000Z
#   Duration: 00:00:03.34, start: 0.000000, bitrate: 431 kb/s
#   Stream #0:0[0x1](und): Video: h264 (Constrained Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x352 [SAR 1:1 DAR 20:11], 254 kb/s, 25 fps, 25 tbr, 25k tbn (default)
#     Metadata:
#       creation_time   : 2019-02-08T01:05:05.000000Z
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 95 kb/s (default)
#     Metadata:
#       creation_time   : 2019-02-08T01:05:05.000000Z
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# File '../data/audios/utterances_final_wav/2_312.wav' already exists. Overwrite? [y/N] Not overwriting - exiting
# ffmpeg version 5.0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with Apple clang version 13.1.6 (clang-1316.0.21.2)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/5.0.1 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-neon
#   libavutil      57. 17.100 / 57. 17.100
#   libavcodec     59. 18.100 / 59. 18.100
#   libavformat    59. 16.100 / 59. 16.100
#   libavdevice    59.  4.100 / 59.  4.100
#   libavfilter     8. 24.100 /  8. 24.100
#   libswscale      6.  4.100 /  6.  4.100
#   libswresample   4.  3.100 /  4.  3.100
#   libpostproc    56.  3.100 / 56.  3.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '../data/audios/utterances_final/2_474.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:01.04, start: 0.000000, bitrate: 1880 kb/s
#   Chapters:
#     Chapter #0:0: start 0.000000, end 1.002000
#       Metadata:
#         title           : 00:00:00.000
#   Stream #0:0[0x1](eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(progressive), 1280x720 [SAR 1:1 DAR 16:9], 1473 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 393 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:2[0x3](eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# File '../data/audios/utterances_final_wav/2_474.wav' already exists. Overwrite? [y/N] Not overwriting - exiting

# %% [markdown]
# ## Librosa
#
# Usually background noises are removed using frequency of foreground and background noise. This doesn't work in our case as the waveshow below shows that dialogue and background laughter have similar frequencies. We can sample foreground audio data to an extent using librosa.

# %%
feat_dict = {}
src_dir = AUDIOS_FOLDER_WAV
hop_length = 512

for f in os.listdir(src_dir):
    if f.endswith(".wav"):
        y, sr = librosa.load(os.path.join(src_dir, f))
        D = librosa.stft(y, hop_length=hop_length)
        S_full, phase = librosa.magphase(D)
        S_filter = librosa.decompose.nn_filter(S_full, aggregate=np.median, metric="cosine")
        S_filter = np.minimum(S_full, S_filter)
        margin_i, margin_v = 2, 4
        power = 2
        mask_v = librosa.util.softmask(S_full - S_filter, margin_v * S_filter, power=power)
        S_foreground = mask_v * S_full
        new_D = S_foreground * phase
        y_foreground = librosa.istft(new_D)
        sf.write(os.path.join(AUDIOS_FOLDER__BGR_WAV, f), y_foreground, sr)
        mfcc = librosa.feature.mfcc(y=y_foreground, sr=sr, n_mfcc=13)
        mfcc_delta = librosa.feature.delta(mfcc)
        rms = librosa.feature.rms(y=y_foreground, hop_length=hop_length)
        rms_delta = librosa.feature.delta(rms)
        zcr = librosa.feature.zero_crossing_rate(y=y_foreground)
        zcr_delta = librosa.feature.delta(zcr)
        tone = librosa.feature.tonnetz(y=y_foreground, sr=sr)
        tempogram = librosa.feature.tempogram(y=y_foreground, sr=sr)
        tempogram_ratio = librosa.feature.tempogram_ratio(y=y_foreground, sr=sr)
        S = librosa.feature.melspectrogram(y=y_foreground, sr=sr, n_mels=128, fmax=8000)
        S_delta = librosa.feature.delta(S)
        spectral_centroid = librosa.feature.spectral_centroid(y=y_foreground, sr=sr, S=S_full)
        
        audio_feature = np.vstack((mfcc, mfcc_delta, rms, rms_delta, zcr, zcr_delta, tone, 
                                   tempogram, tempogram_ratio, S, S_delta, spectral_centroid))
        
        feat_dict[f] = audio_feature

with open('feat_dict_librosa_lld.pickle', 'wb') as handle:
    pickle.dump(feat_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## OpenSmile
# Prosody features extraction
#
# OpenSmile shell script is processing only 493 wave files. Rest threw "Maybe this is not a WAVE file?" <br>
# OpenSmile python is working fine.

# %%
feat_dict = {}

smile_lld = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

# # captured on whole for each video
# smile_predefined = opensmile.Smile(
#     feature_set=opensmile.FeatureSet.eGeMAPSv02,
#     feature_level=opensmile.FeatureLevel.Functionals,
# )
#+smile_predefined.feature_names
#     spredefined = smile_predefined.process_file(os.path.join(src_dir,f))
#     df_concat = pd.concat([slld, spredefined], axis=1)

df = pd.DataFrame(columns=smile_lld.feature_names)


src_dir = AUDIOS_FOLDER__BGR_WAV
for f in os.listdir(src_dir):
    if f.endswith(".wav"):
        spd = smile_lld.process_file(os.path.join(src_dir,f))
        feat_dict[f] = np.transpose(spd.to_numpy())
        df = df.append(spd)

# %%
df.to_csv("framewise_feat_opensmile_lld.csv")
with open('feat_dict_opensmile_lld.pickle', 'wb') as handle:
    pickle.dump(feat_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Frame config changes to align librosa and opensmile features
# Check if we can merge opensmile and librosa features.  <br>
# Try frame parameters for opensmile - https://github.com/audeering/opensmile-python/issues/14 <br>
#
# Tried - <br>
# https://github.com/audeering/opensmile-python/issues/76 <br>
# https://github.com/audeering/opensmile-python/issues/57 <br>
# Configs updated to have frame size of 93ms and frame step of 25ms based on Librosa paper https://conference.scipy.org/proceedings/scipy2015/pdfs/brian_mcfee.pdf <br>
# Package path local for config changes - /Users/shreyaprabhu/opt/miniconda3/lib/python3.9/site-packages/opensmile <br>
#
# ### References
# https://github.com/soujanyaporia/MUStARD <br>
# https://audeering.github.io/opensmile-python/usage.html <br>
# https://github.com/ekayen/prosody_detection <br>
#
# Other methods/libraries tried -
# 1. SOX for converting mp4 to wav file. SOX does not have handler for mp4 as of now. https://github.com/jacksonh/sox.
# 2. Disvoice for prosody feature extraction. Did not work. Had package issues.
# 3. Myprosody library for prosody feature extraction. The code is in initial stages and has hardcoded file paths. Did not work. https://github.com/Shahabks/myprosody

# %%
os.path.dirname(opensmile.__file__)
# Out:
# '/Users/shreyaprabhu/opt/miniconda3/lib/python3.9/site-packages/opensmile'
