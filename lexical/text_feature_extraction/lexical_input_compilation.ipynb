# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("../data/mustard++_text.csv")
data = data.drop(columns=['END_TIME', 'Implicit_Emotion', 'Explicit_Emotion', 'Valence', 'Arousal'])
data.rename(columns={
    'SCENE': 'scene', 'KEY': 'key', 'SENTENCE': 'sentence', 'SPEAKER': 'speaker', 'SHOW' : 'show', 'Sarcasm' : 'sarcasm',
    'Sarcasm_Type' : 'sarcasm_type'}, inplace=True)

# %%
data.head(10)
# Out:
#      scene           key                                           sentence  \
# 0  1_10004  1_10004_c_00  Well, I'm sure that, uh, you...\nhave a lot of...
# 1  1_10004  1_10004_c_01                                        Who was he?
# 2  1_10004  1_10004_c_02    His name is Ron.\nI met him at my prayer group.
# 3  1_10004  1_10004_c_03          How long have you been involved with him?
# 4  1_10004  1_10004_c_04                                      A few months.
# 5  1_10004     1_10004_u  And of those few months, how long have you bee...
# 6  1_10009  1_10009_c_00   FYI, we plan on selling out the human race hard.
# 7  1_10009  1_10009_c_01  In 20 years, who knows what'll happen with any...
# 8  1_10009  1_10009_c_02          I think you and Leonard will be together.
# 9  1_10009  1_10009_c_03                                            You do?
#
#    speaker show  sarcasm sarcasm_type
# 0   PERSON  BBT      NaN          NaN
# 1  SHELDON  BBT      NaN          NaN
# 2   PERSON  BBT      NaN          NaN
# 3  SHELDON  BBT      NaN          NaN
# 4   PERSON  BBT      NaN          NaN
# 5  SHELDON  BBT      0.0         NONE
# 6      AMY  BBT      NaN          NaN
# 7    PENNY  BBT      NaN          NaN
# 8   PERSON  BBT      NaN          NaN
# 9    PENNY  BBT      NaN          NaN

# %%
len(data)
# Out:
# 6041

# %%
context_data = data[data.sarcasm.isnull()]

# %%
context_data.head(10)
# Out:
#       scene           key                                           sentence  \
# 0   1_10004  1_10004_c_00  Well, I'm sure that, uh, you...\nhave a lot of...
# 1   1_10004  1_10004_c_01                                        Who was he?
# 2   1_10004  1_10004_c_02    His name is Ron.\nI met him at my prayer group.
# 3   1_10004  1_10004_c_03          How long have you been involved with him?
# 4   1_10004  1_10004_c_04                                      A few months.
# 6   1_10009  1_10009_c_00   FYI, we plan on selling out the human race hard.
# 7   1_10009  1_10009_c_01  In 20 years, who knows what'll happen with any...
# 8   1_10009  1_10009_c_02          I think you and Leonard will be together.
# 9   1_10009  1_10009_c_03                                            You do?
# 10  1_10009  1_10009_c_04      Yeah.\nI think you're the best couple I know.
#
#     speaker show  sarcasm sarcasm_type
# 0    PERSON  BBT      NaN          NaN
# 1   SHELDON  BBT      NaN          NaN
# 2    PERSON  BBT      NaN          NaN
# 3   SHELDON  BBT      NaN          NaN
# 4    PERSON  BBT      NaN          NaN
# 6       AMY  BBT      NaN          NaN
# 7     PENNY  BBT      NaN          NaN
# 8    PERSON  BBT      NaN          NaN
# 9     PENNY  BBT      NaN          NaN
# 10   PERSON  BBT      NaN          NaN

# %%
grouped_context_data = context_data.drop(columns=['speaker', 'show', 'sarcasm', 'sarcasm_type'])
grouped_context_data = context_data.sort_values(['key'],ascending=False).groupby('scene', as_index=False).agg({'sentence' : ' '.join})  
grouped_context_data.rename(columns={'sentence': 'context'}, inplace=True)
grouped_context_data
# Out:
#              scene                                            context
# 0          1_10004  A few months. How long have you been involved ...
# 1          1_10009  Ah-da-da-da-da! What the hell?! Excuse me? Tha...
# 2           1_1001  It's smashed beyond repair. What are you gonna...
# 3           1_1003  I'm gonna go back and try talking to her again...
# 4          1_10190  Sure. What's up? Leonard, I could use your ass...
# ...            ...                                                ...
# 1197  3_S06E02_398  I mean, he really, really likes Pied Piper. He...
# 1198  3_S06E03_366  Right. Yeah. -we could just buy Hooli. -(laugh...
# 1199  3_S06E05_355  I was just curious to know, like, what's it li...
# 1200  3_S06E06_143  -Were you gonna tell me about this? -No. You g...
# 1201  3_S06E07_272  I realized something. But a few hours later wh...
#
# [1202 rows x 2 columns]

# %%
sarcasm_statements = data.groupby("scene").last()

# %%
sarcasm_statements.rename(columns={'sentence': 'target'}, inplace=True)
sarcasm_statements.head()
# Out:
#                key                                             target  \
# scene
# 1_10004  1_10004_u  And of those few months, how long have you bee...
# 1_10009  1_10009_u  Let the dead man talk. So, why do you think that?
# 1_1001    1_1001_u     What else? Sell it on eBay as "slightly used."
# 1_1003    1_1003_u  Good idea, sit with her. Hold her, comfort her...
# 1_10190  1_10190_u  Well, now that I've given up string theory, I'...
#
#          speaker show  sarcasm sarcasm_type
# scene
# 1_10004  SHELDON  BBT      0.0         NONE
# 1_10009    PENNY  BBT      0.0         NONE
# 1_1001       RAJ  BBT      0.0         NONE
# 1_1003    HOWARD  BBT      1.0          PRO
# 1_10190  SHELDON  BBT      0.0         NONE

# %%
all_data = grouped_context_data.merge(sarcasm_statements, on='scene')

# %%
all_data
# Out:
#              scene                                            context  \
# 0          1_10004  A few months. How long have you been involved ...
# 1          1_10009  Ah-da-da-da-da! What the hell?! Excuse me? Tha...
# 2           1_1001  It's smashed beyond repair. What are you gonna...
# 3           1_1003  I'm gonna go back and try talking to her again...
# 4          1_10190  Sure. What's up? Leonard, I could use your ass...
# ...            ...                                                ...
# 1197  3_S06E02_398  I mean, he really, really likes Pied Piper. He...
# 1198  3_S06E03_366  Right. Yeah. -we could just buy Hooli. -(laugh...
# 1199  3_S06E05_355  I was just curious to know, like, what's it li...
# 1200  3_S06E06_143  -Were you gonna tell me about this? -No. You g...
# 1201  3_S06E07_272  I realized something. But a few hours later wh...
#
#                  key                                             target  \
# 0          1_10004_u  And of those few months, how long have you bee...
# 1          1_10009_u  Let the dead man talk. So, why do you think that?
# 2           1_1001_u     What else? Sell it on eBay as "slightly used."
# 3           1_1003_u  Good idea, sit with her. Hold her, comfort her...
# 4          1_10190_u  Well, now that I've given up string theory, I'...
# ...              ...                                                ...
# 1197  3_S06E02_398_u                  Look, we cannot take blood money.
# 1198  3_S06E03_366_u  The-the same way we can buy America and everyt...
# 1199  3_S06E05_355_u  Well, maybe some time when you're working on s...
# 1200  3_S06E06_143_u  I thought that was the company policy-these days.
# 1201  3_S06E07_272_u                          That you're an alcoholic?
#
#        speaker show  sarcasm sarcasm_type
# 0      SHELDON  BBT      0.0         NONE
# 1        PENNY  BBT      0.0         NONE
# 2          RAJ  BBT      0.0         NONE
# 3       HOWARD  BBT      1.0          PRO
# 4      SHELDON  BBT      0.0         NONE
# ...        ...  ...      ...          ...
# 1197     OTHER   SV      0.0         NONE
# 1198   RICHARD   SV      1.0          PRO
# 1199     OTHER   SV      1.0          PRO
# 1200  GILFOYLE   SV      1.0          ILL
# 1201    DINESH   SV      1.0          ILL
#
# [1202 rows x 8 columns]

# %%
all_data.to_csv("text_data_compiled.csv", index = False)
